# %%
from pathlib import Path
from langchain_community.document_loaders import PyPDFLoader
from langchain_unstructured import UnstructuredLoader
from langchain_core.documents import Document
from typing import List 
from langchain_community.document_loaders import Docx2txtLoader

from langchain_text_splitters import CharacterTextSplitter, RecursiveCharacterTextSplitter, MarkdownHeaderTextSplitter
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_experimental.text_splitter import SemanticChunker
import weaviate 
from weaviate.classes.config import Configure, Property, DataType
from weaviate.util import generate_uuid5
from tqdm import tqdm
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# # 1. Load document (texe, PDF, Markdown, Web,..)

# %%
def load_documents_format(file_path: str) -> List[Document]:
    """
    Load documents using the best loader for each file format.
        
    Returns:
        List of Document objects with page_content and metadata
    """
    path = Path(file_path)
    file_ext = path.suffix.lower()
    
    # PDF files - one Document per page
    if file_ext == '.pdf':
        loader = PyPDFLoader(file_path)
        docs = loader.load()
        return docs
    
    # Word documents - preserves formatting
    elif file_ext == '.docx':
        loader = Docx2txtLoader(file_path)
        docs = loader.load()
        return docs
    
    # Text/markdown files
    elif file_ext == '.txt' or file_ext == '.md':
        with open(file_path, 'r', encoding='utf-8') as f:
            content = f.read()
        return [Document(
            page_content=content,
            metadata={
                "source": str(path),
                "file_type": "text"
            }
        )]
    
def load_multiple_documents(
    directory_path: str,
    file_types: List[str] = None,
    verbose: bool = False
) -> List[Document]:
    """
    Load all documents from a directory using optimal loaders.
        
    Returns:
        List of all loaded Documents
    """
    if file_types is None:
        file_types = ['.pdf', '.docx', '.txt', '.md']
    
    directory = Path(directory_path)
    all_documents = []
    
    for file_type in file_types:
        for file_path in directory.glob(f'*{file_type}'):
            try:
                if verbose:
                    print(f"Loading {file_path.name}...")
                docs = load_documents_format(str(file_path))
                
                all_documents.extend(docs)
                if verbose:
                    print(f"✓ Loaded {len(docs)} documents")
            except Exception as e:
                print(f"✗ Error loading {file_path.name}: {e}")
    
    return all_documents

# %%
documents = load_multiple_documents('documents/', verbose=True)
# Out:
# Loading Privacy Policy f... (1).docx...
# ✓ Loaded 1 documents
# Loading SaaS Agreement f... (1).docx...
# ✓ Loaded 1 documents

# %%
documents[0].metadata
# Out:
# {'source': 'documents\\Privacy Policy f... (1).docx'}

# %%
print(f'Number of documents: {len(documents)}')
# Out:
# Number of documents: 2

# %%
for doc in documents[:3]:
    print(f'Content: {doc.page_content}')  
    print(f'Metadata: {doc.metadata}')
    print('-' * 80)
# Out:
# Content: Chính sách Quyền riêng tư của TechNova Solutions
#
#
#
# Cập nhật lần cuối: Ngày 20 tháng 12 năm 2025
#
#
#
# Chào mừng bạn đến với TechNova Solutions ("Công ty," "chúng tôi," hoặc "của chúng tôi"). Chúng tôi cam kết bảo vệ thông tin cá nhân và quyền riêng tư của bạn. Nếu bạn có bất kỳ câu hỏi hoặc lo ngại nào về chính sách của chúng tôi, hoặc về các thực tiễn của chúng tôi liên quan đến thông tin cá nhân của bạn, vui lòng liên hệ với chúng tôi tại privacy@technovasolutions.io.
#
#
#
# Khi bạn truy cập trang web của chúng tôi https://www.technovasolutions.io, sử dụng ứng dụng di động của chúng tôi, hoặc sử dụng bất kỳ dịch vụ nào của chúng tôi (gọi chung là "Dịch vụ," bao gồm Trang web và Ứng dụng), chúng tôi đánh giá cao việc bạn đã tin tưởng giao phó thông tin cá nhân của mình cho chúng tôi. Chúng tôi rất coi trọng quyền riêng tư của bạn. Trong thông báo quyền riêng tư này, chúng tôi cố gắng giải thích cho bạn một cách rõ ràng nhất có thể về những thông tin chúng tôi thu thập, cách chúng tôi sử dụng và những quyền mà bạn có liên quan đến thông tin đó. Chúng tôi hy vọng bạn dành chút thời gian để đọc kỹ, vì điều này rất quan trọng. Nếu có bất kỳ điều khoản nào trong chính sách quyền riêng tư này mà bạn không đồng ý, vui lòng ngừng sử dụng Dịch vụ của chúng tôi ngay lập tức.
#
#
#
# 1. MỤC LỤC
#
# Thông tin chúng tôi thu thập
#
# Cách chúng tôi sử dụng thông tin của bạn
#
# Cơ sở pháp lý để xử lý thông tin
#
# Chia sẻ thông tin của bạn
#
# Cookie và Công nghệ Theo dõi
#
# Chuyển dữ liệu quốc tế
#
# Lưu giữ dữ liệu
#
# Bảo mật dữ liệu
#
# Quyền riêng tư (GDPR/CCPA)
#
# Quyền riêng tư của trẻ em
#
# Cập nhật chính sách
#
# Thông tin liên hệ
#
# 2. THÔNG TIN CHÚNG TÔI THU THẬP****A. Thông tin cá nhân bạn tiết lộ cho chúng tôi
#
#
#
# Chúng tôi thu thập thông tin cá nhân mà bạn tự nguyện cung cấp cho chúng tôi khi bạn đăng ký trên Dịch vụ, bày tỏ sự quan tâm đến việc nhận thông tin về chúng tôi hoặc các sản phẩm và Dịch vụ của chúng tôi, khi bạn tham gia các hoạt động trên Dịch vụ, hoặc khi bạn liên hệ với chúng tôi.
#
#
#
# Thông tin cá nhân chúng tôi thu thập phụ thuộc vào ngữ cảnh tương tác của bạn với chúng tôi và Dịch vụ, các lựa chọn bạn đưa ra, cũng như các sản phẩm và tính năng bạn sử dụng. Thông tin cá nhân chúng tôi thu thập có thể bao gồm những điều sau:
#
# Dữ liệu Nhận dạng: Tên, tên người dùng hoặc số nhận dạng tương tự, tình trạng hôn nhân, danh xưng, ngày sinh và giới tính.
#
# Dữ liệu Liên hệ: Địa chỉ thanh toán, địa chỉ giao hàng, địa chỉ email và số điện thoại.
#
# Dữ liệu Tài chính: Chi tiết tài khoản ngân hàng và thẻ thanh toán (được xử lý thông qua các bộ xử lý thanh toán bên thứ ba an toàn).
#
# Dữ liệu Hồ sơ: Tên người dùng và mật khẩu của bạn, các giao dịch mua hoặc đơn đặt hàng của bạn, sở thích, tùy chọn, phản hồi và câu trả lời khảo sát của bạn.
#
# Dữ liệu Tiếp thị và Truyền thông: Các tùy chọn của bạn trong việc nhận thông tin tiếp thị từ chúng tôi và các bên thứ ba của chúng tôi, cùng với các tùy chọn truyền thông của bạn.
#
# B. Thông tin được Thu thập Tự động
#
#
#
# Chúng tôi tự động thu thập một số thông tin nhất định khi bạn truy cập, sử dụng hoặc điều hướng Dịch vụ. Thông tin này không tiết lộ danh tính cụ thể của bạn (như tên hoặc thông tin liên hệ của bạn) nhưng có thể bao gồm thông tin về thiết bị và việc sử dụng, chẳng hạn như địa chỉ IP của bạn, đặc điểm trình duyệt và thiết bị, hệ điều hành, tùy chọn ngôn ngữ, URL giới thiệu, tên thiết bị, quốc gia, vị trí, thông tin về cách thức và thời điểm bạn sử dụng Dịch vụ của chúng tôi, và các thông tin kỹ thuật khác.
#
# Dữ liệu Nhật ký và Sử dụng: Thông tin liên quan đến dịch vụ, chẩn đoán, sử dụng và hiệu suất mà máy chủ của chúng tôi tự động thu thập khi bạn truy cập hoặc sử dụng Dịch vụ của chúng tôi và chúng tôi ghi lại trong các tệp nhật ký.
#
# Dữ liệu Thiết bị: Thông tin về máy tính, điện thoại, máy tính bảng hoặc thiết bị khác mà bạn sử dụng để truy cập Dịch vụ.
#
# Dữ liệu Vị trí: Thông tin về vị trí thiết bị của bạn, có thể là chính xác hoặc không chính xác.
#
# 3. CÁCH CHÚNG TÔI SỬ DỤNG THÔNG TIN CỦA BẠN
#
#
#
# Chúng tôi sử dụng thông tin cá nhân được thu thập thông qua Dịch vụ của chúng tôi cho nhiều mục đích kinh doanh được mô tả dưới đây. Chúng tôi xử lý thông tin cá nhân của bạn cho các mục đích này dựa trên lợi ích kinh doanh hợp pháp của chúng tôi, để ký kết hoặc thực hiện hợp đồng với bạn, với sự đồng ý của bạn, và/hoặc để tuân thủ các nghĩa vụ pháp lý của chúng tôi.
#
# Để tạo điều kiện cho việc tạo tài khoản và quá trình đăng nhập: Nếu bạn chọn liên kết tài khoản của mình với chúng tôi đến một tài khoản bên thứ ba (chẳng hạn như tài khoản Google hoặc Facebook của bạn), chúng tôi sử dụng thông tin bạn cho phép chúng tôi thu thập từ các bên thứ ba đó để tạo điều kiện cho việc tạo tài khoản và quá trình đăng nhập nhằm thực hiện hợp đồng.
#
# Để đăng lời chứng thực: Chúng tôi đăng các lời chứng thực trên Dịch vụ của chúng tôi có thể chứa thông tin cá nhân. Trước khi đăng lời chứng thực, chúng tôi sẽ xin sự đồng ý của bạn để sử dụng tên và nội dung của lời chứng thực.
#
# Yêu cầu phản hồi: Chúng tôi có thể sử dụng thông tin của bạn để yêu cầu phản hồi và liên hệ với bạn về việc sử dụng Dịch vụ của chúng tôi.
#
# Để cho phép giao tiếp giữa người dùng với người dùng: Chúng tôi có thể sử dụng thông tin của bạn để cho phép giao tiếp giữa người dùng với người dùng với sự đồng ý của mỗi người dùng.
#
# Để quản lý tài khoản người dùng: Chúng tôi có thể sử dụng thông tin của bạn cho mục đích quản lý tài khoản của chúng tôi và giữ cho tài khoản hoạt động bình thường.
#
# Để gửi thông tin hành chính cho bạn: Chúng tôi có thể sử dụng thông tin cá nhân của bạn để gửi cho bạn thông tin về sản phẩm, dịch vụ và tính năng mới và/hoặc thông tin về những thay đổi đối với các điều khoản, điều kiện và chính sách của chúng tôi.
#
# Để bảo vệ Dịch vụ của chúng tôi: Chúng tôi có thể sử dụng thông tin của bạn như một phần trong nỗ lực của chúng tôi nhằm giữ cho Dịch vụ của chúng tôi an toàn và bảo mật (ví dụ: để giám sát và ngăn chặn gian lận).
#
# Để thực thi các điều khoản, điều kiện và chính sách của chúng tôi: Cho mục đích kinh doanh, để tuân thủ các yêu cầu pháp lý và quy định hoặc liên quan đến hợp đồng của chúng tôi.
#
# 4. CƠ SỞ PHÁP LÝ ĐỂ XỬ LÝ THÔNG TIN
#
#
#
# Nếu bạn ở Khu vực Kinh tế Châu Âu (EEA) hoặc Vương quốc Anh (UK), cơ sở pháp lý của chúng tôi để thu thập và sử dụng thông tin cá nhân được mô tả ở trên sẽ phụ thuộc vào thông tin cá nhân liên quan và ngữ cảnh cụ thể mà chúng tôi thu thập thông tin đó.
#
# Sự đồng ý: Chúng tôi có thể xử lý dữ liệu của bạn nếu bạn đã cho chúng tôi sự đồng ý cụ thể để sử dụng thông tin cá nhân của bạn cho một mục đích cụ thể.
#
# Thực hiện Hợp đồng: Trong trường hợp chúng tôi đã ký kết hợp đồng với bạn, chúng tôi có thể xử lý thông tin cá nhân của bạn để thực hiện các điều khoản của hợp đồng.
#
# Lợi ích Hợp pháp: Chúng tôi có thể xử lý dữ liệu của bạn khi điều đó là cần thiết một cách hợp lý để đạt được các lợi ích kinh doanh hợp pháp của chúng tôi.
#
# Nghĩa vụ Pháp lý: Chúng tôi có thể tiết lộ thông tin của bạn khi chúng tôi có nghĩa vụ pháp lý phải làm như vậy để tuân thủ luật pháp hiện hành, các yêu cầu của chính phủ, một thủ tục tố tụng tư pháp, lệnh của tòa án hoặc quy trình pháp lý.
#
# 5. CHIA SẺ THÔNG TIN CỦA BẠN
#
#
#
# Chúng tôi chỉ chia sẻ thông tin với sự đồng ý của bạn, để tuân thủ luật pháp, để cung cấp dịch vụ cho bạn, để bảo vệ quyền lợi của bạn hoặc để thực hiện các nghĩa vụ kinh doanh.
#
# Nhà cung cấp, Tư vấn viên và các Nhà cung cấp Dịch vụ Bên thứ ba khác: Chúng tôi có thể chia sẻ dữ liệu của bạn với các nhà cung cấp bên thứ ba, nhà cung cấp dịch vụ, nhà thầu hoặc đại lý thực hiện dịch vụ cho chúng tôi hoặc thay mặt chúng tôi và yêu cầu quyền truy cập vào thông tin đó để thực hiện công việc đó. Ví dụ bao gồm xử lý thanh toán, phân tích dữ liệu, gửi email, dịch vụ lưu trữ, dịch vụ khách hàng và các nỗ lực tiếp thị.
#
# Chuyển giao Kinh doanh: Chúng tôi có thể chia sẻ hoặc chuyển giao thông tin của bạn liên quan đến, hoặc trong quá trình đàm phán về, bất kỳ sự sáp nhập, bán tài sản công ty, tài trợ, hoặc mua lại toàn bộ hoặc một phần hoạt động kinh doanh của chúng tôi cho một công ty khác.
#
# Các Công ty Liên kết: Chúng tôi có thể chia sẻ thông tin của bạn với các công ty liên kết của chúng tôi, trong trường hợp đó chúng tôi sẽ yêu cầu các công ty liên kết đó tuân thủ chính sách quyền riêng tư này.
#
# Đối tác Kinh doanh: Chúng tôi có thể chia sẻ thông tin của bạn với các đối tác kinh doanh của chúng tôi để cung cấp cho bạn các sản phẩm, dịch vụ hoặc chương trình khuyến mãi nhất định.
#
# 6. COOKIE VÀ CÔNG NGHỆ THEO DÕI
#
#
#
# Chúng tôi có thể sử dụng cookie và các công nghệ theo dõi tương tự (như web beacon và pixel) để truy cập hoặc lưu trữ thông tin. Thông tin cụ thể về cách chúng tôi sử dụng các công nghệ đó và cách bạn có thể từ chối một số cookie nhất định được nêu trong Chính sách Cookie của chúng tôi.
#
#
#
# Hầu hết các trình duyệt web đều được đặt để chấp nhận cookie theo mặc định. Nếu bạn muốn, bạn thường có thể chọn đặt trình duyệt của mình để xóa cookie và từ chối cookie. Nếu bạn chọn xóa cookie hoặc từ chối cookie, điều này có thể ảnh hưởng đến một số tính năng hoặc dịch vụ của Dịch vụ của chúng tôi.
#
#
#
# 7. CHUYỂN DỮ LIỆU QUỐC TẾ
#
#
#
# Các máy chủ của chúng tôi được đặt tại Hoa Kỳ. Nếu bạn đang truy cập Dịch vụ của chúng tôi từ bên ngoài Hoa Kỳ, vui lòng lưu ý rằng thông tin của bạn có thể được chuyển đến, lưu trữ và xử lý bởi chúng tôi tại các cơ sở của chúng tôi và bởi các bên thứ ba mà chúng tôi có thể chia sẻ thông tin cá nhân của bạn.
#
#
#
# Nếu bạn là cư dân ở Khu vực Kinh tế Châu Âu (EEA) hoặc Vương quốc Anh (UK), thì các quốc gia này có thể không nhất thiết có luật bảo vệ dữ liệu hoặc các luật tương tự khác toàn diện như luật ở quốc gia của bạn. Tuy nhiên, chúng tôi sẽ thực hiện tất cả các biện pháp cần thiết để bảo vệ thông tin cá nhân của bạn theo chính sách quyền riêng tư này và luật pháp hiện hành, bao gồm sử dụng Các Điều khoản Hợp đồng Tiêu chuẩn (SCCs) được Ủy ban Châu Âu phê duyệt.
#
#
#
# 8. LƯU GIỮ DỮ LIỆU
#
#
#
# Chúng tôi sẽ chỉ giữ thông tin cá nhân của bạn trong thời gian cần thiết cho các mục đích được nêu trong chính sách quyền riêng tư này, trừ khi luật pháp yêu cầu hoặc cho phép thời gian lưu giữ dài hơn (chẳng hạn như các yêu cầu về thuế, kế toán hoặc pháp lý khác).
#
#
#
# Khi chúng tôi không còn nhu cầu kinh doanh hợp pháp đang diễn ra để xử lý thông tin cá nhân của bạn, chúng tôi sẽ xóa hoặc ẩn danh thông tin đó, hoặc, nếu điều này là không thể (ví dụ: vì thông tin cá nhân của bạn đã được lưu trữ trong kho lưu trữ dự phòng), thì chúng tôi sẽ lưu trữ thông tin cá nhân của bạn một cách an toàn và cô lập thông tin đó khỏi mọi quá trình xử lý tiếp theo cho đến khi việc xóa là có thể.
#
#
#
# 9. BẢO MẬT DỮ LIỆU
#
#
#
# Chúng tôi đã thực hiện các biện pháp bảo mật kỹ thuật và tổ chức phù hợp được thiết kế để bảo vệ tính bảo mật của bất kỳ thông tin cá nhân nào chúng tôi xử lý. Các biện pháp này bao gồm mã hóa dữ liệu khi nghỉ và khi truyền, tường lửa và kiểm toán bảo mật thường xuyên.
#
#
#
# Tuy nhiên, xin lưu ý rằng chúng tôi không thể đảm bảo rằng bản thân internet an toàn 100%. Mặc dù chúng tôi sẽ cố gắng hết sức để bảo vệ thông tin cá nhân của bạn, việc truyền thông tin cá nhân đến và từ Dịch vụ của chúng tôi là rủi ro của riêng bạn. Bạn chỉ nên truy cập các dịch vụ trong một môi trường an toàn.
#
#
#
# 10. QUYỀN RIÊNG TƯ****A. Đối với Cư dân EEA/UK
#
#
#
# Theo Quy định chung về Bảo vệ Dữ liệu (GDPR), bạn có một số quyền nhất định, bao gồm:
#
# Quyền yêu cầu truy cập và nhận bản sao thông tin cá nhân của bạn.
#
# Quyền yêu cầu đính chính hoặc xóa bỏ.
#
# Quyền hạn chế xử lý thông tin cá nhân của bạn.
#
# Quyền di chuyển dữ liệu.
#
# Quyền phản đối việc xử lý.
#
# B. Đối với Cư dân California
#
#
#
# Đạo luật về Quyền riêng tư của Người tiêu dùng California (CCPA) cung cấp cho cư dân California các quyền cụ thể liên quan đến thông tin cá nhân của họ:
#
# Quyền được Biết: Bạn có quyền yêu cầu chúng tôi tiết lộ những thông tin cá nhân nào chúng tôi thu thập, sử dụng, tiết lộ và bán.
#
# Quyền Xóa: Bạn có quyền yêu cầu xóa thông tin cá nhân của bạn được chúng tôi thu thập hoặc duy trì.
#
# Quyền Từ chối: Bạn có quyền từ chối việc bán thông tin cá nhân của bạn. (Lưu ý: TechNova Solutions không bán thông tin cá nhân).
#
# Quyền Không bị Phân biệt đối xử: Chúng tôi sẽ không phân biệt đối xử với bạn vì đã thực hiện bất kỳ quyền CCPA nào của bạn.
#
# 11. QUYỀN RIÊNG TƯ CỦA TRẺ EM
#
#
#
# Chúng tôi không cố ý thu thập dữ liệu từ hoặc tiếp thị cho trẻ em dưới 18 tuổi. Bằng cách sử dụng Dịch vụ, bạn tuyên bố rằng bạn ít nhất 18 tuổi hoặc bạn là cha mẹ hoặc người giám hộ của trẻ vị thành niên đó và đồng ý cho trẻ vị thành niên phụ thuộc đó sử dụng Dịch vụ. Nếu chúng tôi biết rằng thông tin cá nhân từ người dùng dưới 18 tuổi đã được thu thập, chúng tôi sẽ hủy kích hoạt tài khoản và thực hiện các biện pháp hợp lý để xóa dữ liệu đó khỏi hồ sơ của chúng tôi ngay lập tức.
#
#
#
# 12. CẬP NHẬT CHÍNH SÁCH
#
#
#
# Chúng tôi có thể cập nhật chính sách quyền riêng tư này theo thời gian. Phiên bản cập nhật sẽ được chỉ ra bằng ngày "Sửa đổi" được cập nhật và phiên bản cập nhật sẽ có hiệu lực ngay khi nó có thể truy cập được. Nếu chúng tôi thực hiện các thay đổi quan trọng đối với chính sách quyền riêng tư này, chúng tôi có thể thông báo cho bạn bằng cách đăng thông báo nổi bật về những thay đổi đó hoặc trực tiếp gửi thông báo cho bạn. Chúng tôi khuyến khích bạn thường xuyên xem lại chính sách quyền riêng tư này để được thông báo về cách chúng tôi bảo vệ thông tin của bạn.
#
#
#
# 13. THÔNG TIN LIÊN HỆ
#
#
#
# Nếu bạn có câu hỏi hoặc nhận xét về chính sách này, bạn có thể liên hệ với Cán bộ Bảo vệ Dữ liệu (DPO) của chúng tôi tại:
#
#
#
# TechNova Solutions Inc.
#
#
#
# Attn: Phòng Quyền riêng tư
#
#
#
# 123 Tech Plaza, Suite 500
#
#
#
# San Francisco, CA 94105
#
#
#
# United States
#
#
#
# Email: privacy@technovasolutions.io
#
#
#
# Phone: +1 (800) 555-TECH
# Metadata: {'source': 'documents\\Privacy Policy f... (1).docx'}
# --------------------------------------------------------------------------------
# Content: Hợp đồng Tổng thể về Phần mềm Dịch vụ (SaaS)
#
#
#
# Cập nhật lần cuối: Ngày 20 tháng 12 năm 2025
#
#
#
# Hợp đồng Tổng thể về Phần mềm Dịch vụ này (gọi tắt là "Hợp đồng") được ký kết giữa TechNova Solutions Inc., một công ty Delaware, có trụ sở kinh doanh chính tại 123 Tech Plaza, Suite 500, San Francisco, CA 94105 ("Công ty," "chúng tôi," hoặc "của chúng tôi") và tổ chức hoặc cá nhân tự nhận là khách hàng trong Đơn đặt hàng áp dụng ("Khách hàng" hoặc "bạn").
#
#
#
# BẰNG VIỆC KÝ KẾT ĐƠN ĐẶT HÀNG, NHẤP VÀO "TÔI ĐỒNG Ý," HOẶC SỬ DỤNG DỊCH VỤ, KHÁCH HÀNG ĐỒNG Ý BỊ RÀNG BUỘC BỞI HỢP ĐỒNG NÀY. NẾU BẠN ĐANG THAY MẶT MỘT CÔNG TY KÝ KẾT HỢP ĐỒNG NÀY, BẠN TUYÊN BỐ RẰNG BẠN CÓ THẨM QUYỀN RÀNG BUỘC TỔ CHỨC ĐÓ.
#
#
#
# 1. ĐỊNH NGHĨA
#
# "Người dùng được ủy quyền" có nghĩa là nhân viên, nhà thầu hoặc đại lý của Khách hàng được Khách hàng ủy quyền truy cập và sử dụng Dịch vụ theo tài khoản của Khách hàng.
#
# "Dữ liệu Khách hàng" có nghĩa là tất cả thông tin, dữ liệu và nội dung khác, dưới bất kỳ hình thức hoặc phương tiện nào, được gửi, đăng hoặc truyền tải theo cách khác bởi hoặc thay mặt Khách hàng hoặc Người dùng được ủy quyền thông qua Dịch vụ.
#
# "Tài liệu" có nghĩa là các sổ tay hướng dẫn, sách hướng dẫn và tài liệu hướng dẫn người dùng của Công ty liên quan đến Dịch vụ do Công ty cung cấp cho Khách hàng dưới dạng điện tử hoặc bản cứng.
#
# "Đơn đặt hàng" có nghĩa là một tài liệu đặt hàng hoặc đơn đặt hàng trực tuyến chỉ định các Dịch vụ sẽ được cung cấp theo đây được ký kết giữa Khách hàng và Công ty.
#
# "Dịch vụ" có nghĩa là các dịch vụ phần mềm dưới dạng dịch vụ do Công ty cung cấp như được mô tả trong Đơn đặt hàng áp dụng.
#
# 2. DỊCH VỤ VÀ HỖ TRỢ SAAS
#
#
#
# 2.1 Cung cấp Dịch vụ
#
#
#
# Theo sự tuân thủ của Khách hàng đối với các điều khoản và điều kiện của Hợp đồng này, Công ty theo đây cấp cho Khách hàng quyền truy cập và sử dụng Dịch vụ không độc quyền, không thể chuyển nhượng, không thể cấp phép lại trong suốt Thời hạn, chỉ dành cho các hoạt động kinh doanh nội bộ của Khách hàng.
#
#
#
# 2.2 Truy cập và Bảo mật
#
#
#
# Khách hàng sẽ chịu trách nhiệm về tất cả thông tin đăng nhập và cho tất cả các hoạt động xảy ra dưới tài khoản của Khách hàng. Khách hàng sẽ thông báo ngay cho Công ty về bất kỳ việc sử dụng trái phép mật khẩu hoặc tài khoản nào hoặc bất kỳ hành vi vi phạm bảo mật nào đã biết hoặc bị nghi ngờ khác.
#
#
#
# 2.3 Hỗ trợ Dịch vụ
#
#
#
# Công ty sẽ cung cấp hỗ trợ khách hàng tiêu chuẩn cho các Dịch vụ theo chính sách hỗ trợ tiêu chuẩn của Công ty có hiệu lực tại thời điểm đó. Các cấp độ hỗ trợ cao hơn có thể có sẵn như được chỉ định trong Đơn đặt hàng.
#
#
#
# 2.4 Mức độ Dịch vụ
#
#
#
# Công ty sẽ sử dụng các nỗ lực hợp lý về mặt thương mại để cung cấp Dịch vụ sẵn sàng $99,9%$ thời gian, được đo lường hàng tháng, ngoại trừ việc bảo trì theo lịch trình.
#
#
#
# 3. HẠN CHẾ VÀ TRÁCH NHIỆM
#
#
#
# 3.1 Hạn chế Sử dụng
#
#
#
# Khách hàng sẽ không, và sẽ không cho phép bất kỳ Người dùng được ủy quyền nào:
#
# Sao chép, sửa đổi hoặc tạo các tác phẩm phái sinh của Dịch vụ hoặc Tài liệu.
#
# Kỹ thuật đảo ngược, tháo rời hoặc dịch ngược Dịch vụ.
#
# Sử dụng Dịch vụ theo bất kỳ cách nào hoặc cho bất kỳ mục đích nào vi phạm, chiếm đoạt hoặc vi phạm quyền sở hữu trí tuệ hoặc quyền khác của bất kỳ người nào.
#
# Tải lên hoặc truyền tải bất kỳ vi-rút, phần mềm độc hại hoặc mã độc hại nào khác.
#
# Truy cập Dịch vụ để xây dựng một sản phẩm hoặc dịch vụ cạnh tranh.
#
# 3.2 Nghĩa vụ của Khách hàng
#
#
#
# Khách hàng chịu trách nhiệm về (a) nội dung của Dữ liệu Khách hàng; (b) tính chính xác, chất lượng và tính hợp pháp của Dữ liệu Khách hàng; và (c) tuân thủ tất cả các luật hiện hành khi sử dụng Dịch vụ.
#
#
#
# 4. BẢO MẬT
#
#
#
# 4.1 Thông tin Bảo mật
#
#
#
# Mỗi bên ("Bên Nhận") hiểu rằng bên kia ("Bên Tiết lộ") đã tiết lộ hoặc có thể tiết lộ thông tin kinh doanh, kỹ thuật hoặc tài chính liên quan đến hoạt động kinh doanh của Bên Tiết lộ (sau đây gọi là "Thông tin Bảo mật").
#
#
#
# 4.2 Bảo vệ Thông tin
#
#
#
# Bên Nhận đồng ý: (i) thực hiện các biện pháp phòng ngừa hợp lý để bảo vệ Thông tin Bảo mật đó, và (ii) không sử dụng (trừ trường hợp thực hiện Dịch vụ hoặc được cho phép khác theo đây) hoặc tiết lộ cho bất kỳ bên thứ ba nào bất kỳ Thông tin Bảo mật nào như vậy.
#
#
#
# 5. QUYỀN SỞ HỮU TRÍ TUỆ
#
#
#
# 5.1 Quyền Sở hữu của Công ty
#
#
#
# Công ty sở hữu và giữ lại tất cả quyền, quyền sở hữu và lợi ích đối với (a) Dịch vụ và Tài liệu, và tất cả các cải tiến hoặc sửa đổi đối với chúng; (b) bất kỳ phần mềm, ứng dụng, phát minh hoặc công nghệ nào khác được phát triển liên quan đến Dịch vụ Triển khai hoặc hỗ trợ; và (c) tất cả các quyền sở hữu trí tuệ liên quan đến bất kỳ điều nào nói trên.
#
#
#
# 5.2 Quyền Sở hữu Dữ liệu Khách hàng
#
#
#
# Khách hàng sở hữu và giữ lại tất cả quyền, quyền sở hữu và lợi ích đối với Dữ liệu Khách hàng. Khách hàng cấp cho Công ty quyền và giấy phép không độc quyền, trên toàn thế giới, miễn phí bản quyền để thu thập, sử dụng, sao chép, lưu trữ, truyền tải, sửa đổi và tạo các tác phẩm phái sinh của Dữ liệu Khách hàng chỉ trong phạm vi cần thiết để cung cấp Dịch vụ cho Khách hàng.
#
#
#
# 5.3 Phản hồi
#
#
#
# Nếu Khách hàng hoặc bất kỳ nhân viên hoặc nhà thầu nào của Khách hàng gửi hoặc truyền tải bất kỳ thông tin liên lạc hoặc tài liệu nào cho Công ty đề xuất hoặc khuyến nghị thay đổi đối với Dịch vụ ("Phản hồi"), Công ty được tự do sử dụng Phản hồi đó mà không phải chịu bất kỳ khoản phí hoặc sự quy kết nào.
#
#
#
# 6. PHÍ VÀ THANH TOÁN
#
#
#
# 6.1 Phí
#
#
#
# Khách hàng sẽ thanh toán cho Công ty các khoản phí được quy định trong Đơn đặt hàng áp dụng ("Phí"). Tất cả các khoản Phí đều không được hoàn lại trừ khi được quy định rõ ràng trong Hợp đồng này.
#
#
#
# 6.2 Lập hóa đơn và Thanh toán
#
#
#
# Trừ khi có quy định khác trong Đơn đặt hàng, tất cả các khoản Phí đến hạn thanh toán ba mươi (30) ngày kể từ ngày lập hóa đơn. Các khoản thanh toán chậm sẽ chịu lãi suất $1,5%$ mỗi tháng hoặc mức lãi suất cao nhất được pháp luật cho phép, tùy theo mức nào thấp hơn.
#
#
#
# 6.3 Thuế
#
#
#
# Phí không bao gồm bất kỳ khoản thuế, phí, lệ phí hoặc các khoản đánh giá tương tự của chính phủ dưới bất kỳ hình thức nào, bao gồm thuế giá trị gia tăng, thuế bán hàng, thuế sử dụng hoặc thuế khấu lưu (gọi chung là "Thuế"). Khách hàng chịu trách nhiệm thanh toán tất cả các khoản Thuế liên quan đến việc mua hàng của mình theo đây.
#
#
#
# 7. THỜI HẠN VÀ CHẤM DỨT
#
#
#
# 7.1 Thời hạn
#
#
#
# Thời hạn của Hợp đồng này sẽ bắt đầu vào ngày được quy định trong Đơn đặt hàng đầu tiên và tiếp tục cho đến khi tất cả các Đơn đặt hàng hết hạn hoặc bị chấm dứt.
#
#
#
# 7.2 Chấm dứt vì Lý do
#
#
#
# Mỗi bên có thể chấm dứt Hợp đồng này vì lý do: (i) khi có thông báo bằng văn bản ba mươi (30) ngày cho bên kia về hành vi vi phạm vật chất nếu hành vi vi phạm đó không được khắc phục khi hết thời hạn đó; hoặc (ii) nếu bên kia trở thành đối tượng của đơn yêu cầu phá sản hoặc bất kỳ thủ tục tố tụng nào khác liên quan đến khả năng thanh toán.
#
#
#
# 7.3 Hiệu lực Chấm dứt
#
#
#
# Khi chấm dứt, Khách hàng sẽ ngay lập tức ngừng tất cả việc sử dụng Dịch vụ và Tài liệu. Công ty sẽ cung cấp Dữ liệu Khách hàng cho Khách hàng để xuất trong khoảng thời gian ba mươi (30) ngày sau khi chấm dứt.
#
#
#
# 8. BẢO HÀNH VÀ TUYÊN BỐ TỪ CHỐI
#
#
#
# 8.1 Bảo hành Chung
#
#
#
# Mỗi bên tuyên bố và đảm bảo rằng mình có quyền và thẩm quyền pháp lý để ký kết Hợp đồng này.
#
#
#
# 8.2 Bảo hành của Công ty
#
#
#
# Công ty đảm bảo rằng Dịch vụ sẽ hoạt động trong mọi khía cạnh vật chất theo Tài liệu. Biện pháp khắc phục duy nhất của Khách hàng đối với việc vi phạm bảo hành này là Công ty sử dụng các nỗ lực hợp lý về mặt thương mại để khắc phục sự không phù hợp.
#
#
#
# 8.3 Tuyên bố Từ chối
#
#
#
# NGOẠI TRỪ NHƯ ĐƯỢC QUY ĐỊNH RÕ RÀNG TRONG ĐÂY, CÁC DỊCH VỤ ĐƯỢC CUNG CẤP "NGUYÊN TRẠNG" VÀ CÔNG TY TUYÊN BỐ TỪ CHỐI TẤT CẢ CÁC BẢO HÀNH, DÙ LÀ RÕ RÀNG, NGỤ Ý, THEO LUẬT ĐỊNH HAY CÁCH KHÁC, BAO GỒM BẤT KỲ BẢO HÀNH NGỤ Ý NÀO VỀ KHẢ NĂNG BÁN ĐƯỢC, SỰ PHÙ HỢP CHO MỘT MỤC ĐÍCH CỤ THỂ HOẶC QUYỀN SỞ HỮU.
#
#
#
# 9. GIỚI HẠN TRÁCH NHIỆM PHÁP LÝ
#
#
#
# TRONG MỌI TRƯỜNG HỢP, KHÔNG BÊN NÀO PHẢI CHỊU TRÁCH NHIỆM PHÁP LÝ ĐỐI VỚI BẤT KỲ THIỆT HẠI GIÁN TIẾP, MANG TÍNH CHẤT TRỪNG PHẠT, ĐẶC BIỆT, MANG TÍNH CHẤT MẪU, NGẪU NHIÊN, HỆ QUẢ HOẶC CÁC THIỆT HẠI KHÁC DƯỚI BẤT KỲ HÌNH THỨC HOẶC LOẠI NÀO (BAO GỒM MẤT DỮ LIỆU, DOANH THU, LỢI NHUẬN HOẶC VIỆC SỬ DỤNG). TỔNG TRÁCH NHIỆM PHÁP LÝ CỦA MỖI BÊN SẼ KHÔNG VƯỢT QUÁ SỐ TIỀN KHÁCH HÀNG ĐÃ THANH TOÁN HOẶC PHẢI THANH TOÁN CHO CÔNG TY TRONG KHOẢNG THỜI GIAN MƯỜI HAI (12) THÁNG NGAY TRƯỚC SỰ KIỆN PHÁT SINH KHIẾU NẠI.
#
#
#
# 10. BỒI THƯỜNG
#
#
#
# 10.1 Bồi thường của Công ty
#
#
#
# Công ty sẽ bảo vệ Khách hàng chống lại bất kỳ khiếu nại nào của bên thứ ba rằng Dịch vụ vi phạm bằng sáng chế hoặc bản quyền của Hoa Kỳ và sẽ bồi thường cho Khách hàng đối với bất kỳ thiệt hại nào cuối cùng được tòa án có thẩm quyền phán quyết chống lại Khách hàng do khiếu nại đó.
#
#
#
# 10.2 Bồi thường của Khách hàng
#
#
#
# Khách hàng sẽ bảo vệ Công ty chống lại bất kỳ khiếu nại nào của bên thứ ba phát sinh từ Dữ liệu Khách hàng hoặc việc Khách hàng sử dụng Dịch vụ vi phạm Hợp đồng này.
#
#
#
# 11. ĐIỀU KHOẢN CHUNG
#
#
#
# 11.1 Luật Điều chỉnh
#
#
#
# Hợp đồng này sẽ được điều chỉnh bởi luật pháp của Bang California mà không liên quan đến các quy định xung đột pháp luật của bang đó.
#
#
#
# 11.2 Toàn bộ Thỏa thuận
#
#
#
# Hợp đồng này, bao gồm tất cả các Đơn đặt hàng, tạo thành toàn bộ thỏa thuận giữa các bên và thay thế tất cả các thỏa thuận và hiểu biết trước đây.
#
#
#
# 11.3 Chuyển nhượng
#
#
#
# Không bên nào có thể chuyển nhượng Hợp đồng này mà không có sự đồng ý trước bằng văn bản của bên kia, ngoại trừ trường hợp sáp nhập, mua lại hoặc bán tất cả hoặc phần lớn tài sản.
#
#
#
# 11.4 Liên hệ
#
#
#
# Tất cả các thông báo theo Hợp đồng này phải được lập thành văn bản và gửi đến:
#
#
#
# TechNova Solutions Inc.
#
#
#
# Phòng Pháp lý
#
#
#
# 123 Tech Plaza, Suite 500
#
#
#
# San Francisco, CA 94105
#
#
#
# Email: legal@technovasolutions.io
# Metadata: {'source': 'documents\\SaaS Agreement f... (1).docx'}
# --------------------------------------------------------------------------------

# %% [markdown]
# # 3. Chunking
#     - Fixed
#     - Recursive ("\n\n", "\n", " ", "")
#     - Semantic
#     - Markdown character
#     - LLM-based (context-aware)

# %%
def chunk_documents(
    documents: List[Document],
    strategy: str = 'recursive',
    chunk_size: int = 500,
    chunk_overlap: int = 50
) -> List[Document]:
        
        chunks = []
        if strategy == 'fixed':
            text_splitter = CharacterTextSplitter(
                chunk_size=chunk_size, 
                chunk_overlap=chunk_overlap
            )
            chunks = text_splitter.split_documents(documents)
            
        elif strategy == "recursive":
            splitter = RecursiveCharacterTextSplitter(
                chunk_size=chunk_size,
                chunk_overlap=chunk_overlap,
                separators=["\n\n", "\n", " ", ""]
            )
            chunks = splitter.split_documents(documents)
            
        elif strategy == 'markdown':
            header_splitter = MarkdownHeaderTextSplitter(
                headers_to_split_on=[
                    ("#", "Header 1"),
                    ("##", "Header 2"),
                    ("###", "Header 3"),
                ]
            )
            chunks = header_splitter.split_documents(documents)
        
        elif strategy == 'semantic':
            embeddings = OpenAIEmbeddings()
            text_splitter = SemanticChunker(
                embeddings=embeddings,
                breakpoint_threshold_type="percentile"
            )
            chunks = text_splitter.split_documents(documents)
        
        elif strategy == 'context-aware':
            splitter = RecursiveCharacterTextSplitter(
                chunk_size=chunk_size, 
                chunk_overlap=chunk_overlap, 
                separators=["\n\n", "\n", " ", ""]
            )
            chunks = splitter.split_documents(documents)
            
            # Add context description using LLM
            prompt_template = PromptTemplate.from_template(
"""You are an expert at summarizing information for retrieval.
                
Analyze the following text chunk and provide a brief, high-level context description.
Focus on the main topic, entities, or event described.

Text Chunk:
"{chunk_text}"

Context Description:"""
            )
            
            llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=1.0)
            chain = prompt_template | llm | StrOutputParser()
            
            for chunk in tqdm(chunks):
                context = chain.invoke({'chunk_text': chunk.page_content})
                chunk.metadata['context_description'] = context.strip()
        
        else:
            raise ValueError(f"Unknown chunking strategy: {strategy}")
        
        return chunks

# %%
chunked_docs = chunk_documents(documents, strategy='recursive', chunk_size=500, chunk_overlap=50)

# %%
print(f"Number of chunks created: {len(chunked_docs)}")
# Out:
# Number of chunks created: 66

# %%
for i, doc in enumerate(chunked_docs[:3]):
    print(f"Chunk {i}: {doc.page_content}")
    print("-" * 80)
# Out:
# Chunk 0: Chính sách Quyền riêng tư của TechNova Solutions
#
#
#
# Cập nhật lần cuối: Ngày 20 tháng 12 năm 2025
#
#
#
# Chào mừng bạn đến với TechNova Solutions ("Công ty," "chúng tôi," hoặc "của chúng tôi"). Chúng tôi cam kết bảo vệ thông tin cá nhân và quyền riêng tư của bạn. Nếu bạn có bất kỳ câu hỏi hoặc lo ngại nào về chính sách của chúng tôi, hoặc về các thực tiễn của chúng tôi liên quan đến thông tin cá nhân của bạn, vui lòng liên hệ với chúng tôi tại privacy@technovasolutions.io.
# --------------------------------------------------------------------------------
# Chunk 1: Khi bạn truy cập trang web của chúng tôi https://www.technovasolutions.io, sử dụng ứng dụng di động của chúng tôi, hoặc sử dụng bất kỳ dịch vụ nào của chúng tôi (gọi chung là "Dịch vụ," bao gồm Trang web và Ứng dụng), chúng tôi đánh giá cao việc bạn đã tin tưởng giao phó thông tin cá nhân của mình cho chúng tôi. Chúng tôi rất coi trọng quyền riêng tư của bạn. Trong thông báo quyền riêng tư này, chúng tôi cố gắng giải thích cho bạn một cách rõ ràng nhất có thể về những thông tin chúng tôi thu
# --------------------------------------------------------------------------------
# Chunk 2: ràng nhất có thể về những thông tin chúng tôi thu thập, cách chúng tôi sử dụng và những quyền mà bạn có liên quan đến thông tin đó. Chúng tôi hy vọng bạn dành chút thời gian để đọc kỹ, vì điều này rất quan trọng. Nếu có bất kỳ điều khoản nào trong chính sách quyền riêng tư này mà bạn không đồng ý, vui lòng ngừng sử dụng Dịch vụ của chúng tôi ngay lập tức.
# --------------------------------------------------------------------------------

# %% [markdown]
# # 4. Store to Vector DB
#     - Connect to DB
#     - Get/Create collection (vectorizer, reranker, properties(for metadata filtering))
#     - Load doc to collection

# %%
# Connect to Weaviate instance
client = weaviate.connect_to_local(
    port=8080, 
    grpc_port=50051
)
# Out:
# e:\Individual\Projects\project_meetly_flask\.venv\Lib\site-packages\weaviate\warnings.py:133: DeprecationWarning: Dep005: You are using weaviate-client version 4.10.2. The latest version is 4.19.0.
#             Consider upgrading to the latest version. See https://weaviate.io/developers/weaviate/client-libraries/python for details.
#   warnings.warn(

# %%
collection_name = "ProjectDocuments"

# Check if collection exists
if client.collections.exists(collection_name):
    client.collections.delete(collection_name)
else:
    # Create new collection
    client.collections.create(
        name=collection_name,
        vectorizer_config=Configure.Vectorizer.text2vec_transformers(),
        reranker_config=Configure.Reranker.transformers(),
        properties=[
            Property(name='content', data_type=DataType.TEXT, vectorize_property=True),
            Property(name='source', data_type=DataType.TEXT, vectorize_property=False),
        ]
    )

# %%
collection = client.collections.get(collection_name)
# Inser documents into the collection
with collection.batch.dynamic() as batch:
    for doc in tqdm(chunked_docs):
        properties = {
            'content': doc.page_content,
            'source': doc.metadata.get('source', ''),
        }
        
        batch.add_object(
            properties=properties,
            uuid=generate_uuid5(doc.page_content)
        )
# Out:
# 100%|██████████| 66/66 [00:00<00:00, 15708.11it/s]

# %%
# Check for errors
if len(collection.batch.failed_objects) > 0:
    print(f"Errors occurred: {len(collection.batch.failed_objects)} objects failed")
else:
    print("All documents stored successfully!")
# Out:
# All documents stored successfully!

# %%
results = collection.query.fetch_objects(limit=3, include_vector=True)
for obj in results.objects:
    print("Properties:", obj.properties)
    print("Vectors:", obj.vector)

# %%
result = collection.aggregate.over_all(total_count=True)
print(f"Total objects in collection: {result.total_count}")
# Out:
# Total objects in collection: 57

# %%
client.close()
